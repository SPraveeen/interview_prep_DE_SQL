# %% [markdown]
# # What to learn
#     - Basics of SparkSQL
#     - How to register **External tables** and **Managed Tables**
#     - Focusing on SQL hands-on {subqueries/aggregation/windows/cte}
#     - **Functions** in SparkSQL (built-in and user-defined)
#     - Row-Level Security and Data Masking --> very important
#     - Delta Live Tables
#     - Delta lake with SQL. -> Open table Format

# %% [markdown]
# # Prerequisites
#     - Azure Cloud
#     - computing engines -> databricks

# %% [markdown]
# # What is SparkSQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
