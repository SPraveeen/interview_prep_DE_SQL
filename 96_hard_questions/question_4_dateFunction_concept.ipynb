# %% [markdown]
# ## datepart, dateadd, datediff

# %% [markdown]
# # date part

# %% [raw]
# select datepart(day,'2022-01-23')
# # o/p -> it will be day -> 23
#
# select datepart(week,'2022-01-23')
# # o/p -> it will be week -> 5
#
# select datepart(month,'2022-01-23')
# # o/p -> it will be month -> 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # date add

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# # similarly month, year, week -> we can add

# %% [markdown]
# # datediff

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## basic question to find shipment details

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
select getdate() 
-- getting todays date

# %% [markdown]
# ![image.png](attachment:image.png)
